# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
customers = pd.read_csv('customers.csv')
customers
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
customers.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
customers.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
customers.isnull()
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False   False  False               False                   False
# 1         False   False  False               False                   False
# 2         False   False  False               False                   False
# 3         False   False  False               False                   False
# 4         False   False  False               False                   False
# ..          ...     ...    ...                 ...                     ...
# 195       False   False  False               False                   False
# 196       False   False  False               False                   False
# 197       False   False  False               False                   False
# 198       False   False  False               False                   False
# 199       False   False  False               False                   False
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(6, 6))
plt.scatter(x='Age', y='Spending Score (1-100)',  data=customers, s=60)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Spending Score (1-100) vs Age')
# Out:
# Text(0.5, 1.0, 'Spending Score (1-100) vs Age')

# %%
customers_variables = customers.drop(['CustomerID','Gender','Annual Income (k$)'],axis=1)
print(customers.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
customers_norm=customers_variables

# %%
wcss = []

for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, max_iter=300)
    kmeans.fit(customers_norm)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(6, 6))
plt.plot(range(1, 20), wcss)
plt.title("Elbow method")
plt.plot(range(1,20),wcss, linewidth=2, color="blue", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,20,1))
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
clustering = KMeans(n_clusters=5,max_iter =300)
clustering.fit(customers_norm)
# Out:
# KMeans(n_clusters=5)

# %%
km1 = KMeans(algorithm='auto',copy_x=True, init='k-means++', max_iter=300,
             n_clusters=5,n_init=10,random_state=None,tol=0.001,verbose=1)

# %%
km1.fit(customers_norm)
y = km1.predict(customers_norm)
# Out:
# Initialization complete
# Iteration 0, inertia 29090.0
# Iteration 1, inertia 24619.737753375925
# Iteration 2, inertia 24262.522448555734
# Iteration 3, inertia 24141.56984019947
# Iteration 4, inertia 24127.519108084893
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 43965.0
# Iteration 1, inertia 32680.187909549968
# Iteration 2, inertia 29309.15615179872
# Iteration 3, inertia 26969.992180321715
# Iteration 4, inertia 25082.700019403706
# Iteration 5, inertia 24339.1517704361
# Iteration 6, inertia 24049.624054762942
# Converged at iteration 6: center shift 0.2551612612394384 within tolerance 0.2864731583333332.
# Initialization complete
# Iteration 0, inertia 36657.0
# Iteration 1, inertia 30705.102497207492
# Iteration 2, inertia 28538.26763888435
# Iteration 3, inertia 26068.169506078553
# Iteration 4, inertia 24643.02619546621
# Iteration 5, inertia 24182.41560016193
# Iteration 6, inertia 24144.069019888655
# Converged at iteration 6: strict convergence.
# Initialization complete
# Iteration 0, inertia 27411.0
# Iteration 1, inertia 24005.498018148435
# Iteration 2, inertia 23918.161696063464
# Converged at iteration 2: center shift 0.2571893051780507 within tolerance 0.2864731583333332.
# Initialization complete
# Iteration 0, inertia 32597.0
# Iteration 1, inertia 26427.815656716335
# Iteration 2, inertia 25075.883212332243
# Iteration 3, inertia 24224.639917819626
# Iteration 4, inertia 24093.90361170353
# Iteration 5, inertia 24051.053484130625
# Converged at iteration 5: center shift 0.2742423990071907 within tolerance 0.2864731583333332.
# Initialization complete
# Iteration 0, inertia 42572.0
# Iteration 1, inertia 29549.76189069676
# Iteration 2, inertia 25112.879561731886
# Iteration 3, inertia 24369.022695405976
# Iteration 4, inertia 24222.5940933812
# Iteration 5, inertia 24196.466731554192
# Iteration 6, inertia 24145.923713744272
# Converged at iteration 6: center shift 0.17418131983590124 within tolerance 0.2864731583333332.
# Initialization complete
# Iteration 0, inertia 33638.0
# Iteration 1, inertia 24709.15957532099
# Iteration 2, inertia 24424.376497781777
# Iteration 3, inertia 24157.849708261514
# Iteration 4, inertia 24122.694510084733
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 42452.0
# Iteration 1, inertia 25786.64656906426
# Iteration 2, inertia 23967.834970692857
# Iteration 3, inertia 23921.905790494333
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 39119.0
# Iteration 1, inertia 24768.27750934173
# Iteration 2, inertia 24073.258124266005
# Iteration 3, inertia 24007.798810080214
# Iteration 4, inertia 23960.708057586573
# Iteration 5, inertia 23909.347423320207
# Converged at iteration 5: center shift 0.2078677416570689 within tolerance 0.2864731583333332.
# Initialization complete
# Iteration 0, inertia 34292.0
# Iteration 1, inertia 24566.879388155037
# Iteration 2, inertia 24175.702790097035
# Iteration 3, inertia 24145.923713744272
# Converged at iteration 3: center shift 0.17418131983590124 within tolerance 0.2864731583333332.

# %%
customers_norm['label'] =y
customers["label"] = y

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='Age', y='Spending Score (1-100)', hue="label",palette=['green','orange','red','purple','blue'],
                data=customers_norm, s=60)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Spending Score (1-100) vs Age')
# Out:
# Text(0.5, 1.0, 'Spending Score (1-100) vs Age')
