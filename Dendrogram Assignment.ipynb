# %% [markdown]
# # Dendogram Assignment

# %% [markdown]
# Data:[[5,3], [10,15], [15,12], [24,10], [30,30], [85,70], [71,80], [60,78], [70,55], [80,91]]
# 1. Using the np.array function create an np array from the data given above.
# 2. Generate a scatter plot for the data.
# 3. Plot dendrogram to visualize the clustering linkage

# %%
Data=[[5,3], [10,15], [15,12], [24,10], [30,30], [85,70], [71,80], [60,78], [70,55], [80,91]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ar1=np.array([[5,3], [10,15], [15,12], [24,10], [30,30], [85,70], [71,80], [60,78], [70,55], [80,91]])
ar1
# Out:
# array([[ 5,  3],
#        [10, 15],
#        [15, 12],
#        [24, 10],
#        [30, 30],
#        [85, 70],
#        [71, 80],
#        [60, 78],
#        [70, 55],
#        [80, 91]])

# %%
plt.scatter(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter plot of random data')
plt.show()

# %%
x=

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
x = np.random.rand(100)
y = np.random.rand(100)

# Create a scatter plot
plt.scatter(x, y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter plot of random data')
plt.show()

# Perform clustering and generate dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

Z = linkage(np.column_stack((x, y)))
dendrogram(Z)
plt.xlabel('Index of data points')
plt.ylabel('Distance')
plt.title('Dendrogram of clustered data')
plt.show()
